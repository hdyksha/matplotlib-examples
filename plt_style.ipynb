# %%
import sys
sys.version
# Out:
# '3.5.2 |Anaconda 4.1.1 (x86_64)| (default, Jul  2 2016, 17:52:12) \n[GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.available
# Out:
# ['ggplot',
#  'seaborn-dark-palette',
#  'seaborn-poster',
#  'grayscale',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-talk',
#  'dark_background',
#  'seaborn-bright',
#  'seaborn-white',
#  'bmh',
#  'seaborn-colorblind',
#  'seaborn-pastel',
#  'seaborn-dark',
#  'fivethirtyeight',
#  'seaborn-notebook',
#  'seaborn-darkgrid',
#  'classic',
#  'seaborn-whitegrid',
#  'seaborn-paper',
#  'seaborn-ticks']

# %%
ymax = 4*np.pi #4π
x = np.linspace(0, ymax, 100)
funcs = [("sin", np.sin), ("cos", np.cos), ("myfunc1", lambda x: 2*x/ymax-1)]
linestyles = ['solid', 'dashed', 'dashdot']
linewidths = [1, 3, 5]

mplstyles = [
    'seaborn-whitegrid',
    'seaborn-colorblind',
    'seaborn-deep',
    'ggplot'
]
for mplstyle in mplstyles:
    with plt.style.context((mplstyle)):
        fig, ax = plt.subplots()
        for f, linestyle, linewidth in zip(funcs, linestyles, linewidths):
            name, impl = f
            ax.plot(x, impl(x), label=name, linestyle=linestyle, linewidth=linewidth)

        ax.set_title(mplstyle)
        ax.legend(loc='lower right')
        plt.show()

# %% [markdown]
# **NOTE:** The styles don't work for points of scatter plot(?)

# %%
import pandas as pd
from sklearn import datasets
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
with plt.style.context(('ggplot')):
    fig, ax = plt.subplots()

    species = df['species'].unique() #  ['setsa', 'versicolor', 'virginica']
    markers = ['o', 's', '^']
    for sp, marker in zip(species, markers):
        sp_df = df[df['species'] == sp]
        x = sp_df['sepal length (cm)']
        y = sp_df['sepal width (cm)']
        ax.scatter(x, y, marker=marker, label=sp)

    ax.legend()
    ax.grid(True)

    plt.show()
